# %%
import numpy as np
import pandas as pd
import pandas_datareader as dr

# %%
string_data = pd.Series(['aardvark','artichoke',np.nan,'avocado'])

# %%
string_data
# Out:
# 0     aardvark
# 1    artichoke
# 2          NaN
# 3      avocado
# dtype: object

# %%
string_data.isnull()
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# dtype: bool

# %%
string_data[0] =None

# %%
string_data.isnull()
# Out:
# 0     True
# 1    False
# 2     True
# 3    False
# dtype: bool

# %%
from numpy import nan as NA

# %%
data = pd.Series([1,NA,3.5,NA,7])

# %%
data.dropna()
# Out:
# 0    1.0
# 2    3.5
# 4    7.0
# dtype: float64

# %%
data[data.notnull()]
# Out:
# 0    1.0
# 2    3.5
# 4    7.0
# dtype: float64

# %%
data = pd.DataFrame([[1.,6.5,3.],[1.,NA,NA],[NA,NA,NA],[NA,6.5,3.]])

# %%
cleaned = data.dropna()

# %%
cleaned
# Out:
#      0    1    2
# 0  1.0  6.5  3.0

# %%
data.dropna(how='all')
# Out:
#      0    1    2
# 0  1.0  6.5  3.0
# 1  1.0  NaN  NaN
# 3  NaN  6.5  3.0

# %%
data[4] =NA

# %%
data
# Out:
#      0    1    2   4
# 0  1.0  6.5  3.0 NaN
# 1  1.0  NaN  NaN NaN
# 2  NaN  NaN  NaN NaN
# 3  NaN  6.5  3.0 NaN

# %%
data
# Out:
#      0    1    2   4
# 0  1.0  6.5  3.0 NaN
# 1  1.0  NaN  NaN NaN
# 2  NaN  NaN  NaN NaN
# 3  NaN  6.5  3.0 NaN

# %%
data.dropna(axis=1,how='all')
# Out:
#      0    1    2
# 0  1.0  6.5  3.0
# 1  1.0  NaN  NaN
# 2  NaN  NaN  NaN
# 3  NaN  6.5  3.0

# %%
df=pd.DataFrame(np.random.randn(7,3))

# %%
df.iloc[:4,1]=NA

# %%
df.iloc[:2,2]=NA

# %%
df
# Out:
#           0         1         2
# 0       NaN       NaN       NaN
# 1  0.610922       NaN       NaN
# 2 -0.170320       NaN  0.473399
# 3 -0.487708       NaN  0.712893
# 4  0.524288  0.363506  0.620252
# 5 -0.613728 -0.993737 -0.046311
# 6 -1.627440 -0.363428 -0.844697

# %%
df.dropna()
# Out:
#           0         1         2
# 4  0.524288  0.363506  0.620252
# 5 -0.613728 -0.993737 -0.046311
# 6 -1.627440 -0.363428 -0.844697

# %%
df.dropna(thresh=2)
# Out:
#           0         1         2
# 2 -0.170320       NaN  0.473399
# 3 -0.487708       NaN  0.712893
# 4  0.524288  0.363506  0.620252
# 5 -0.613728 -0.993737 -0.046311
# 6 -1.627440 -0.363428 -0.844697

# %%
df.fillna(0)
# Out:
#           0         1         2
# 0  0.000000  0.000000  0.000000
# 1  0.610922  0.000000  0.000000
# 2 -0.170320  0.000000  0.473399
# 3 -0.487708  0.000000  0.712893
# 4  0.524288  0.363506  0.620252
# 5 -0.613728 -0.993737 -0.046311
# 6 -1.627440 -0.363428 -0.844697

# %%
df.fillna({1:0.5,2:0})
# Out:
#           0         1         2
# 0       NaN  0.500000  0.000000
# 1  0.610922  0.500000  0.000000
# 2 -0.170320  0.500000  0.473399
# 3 -0.487708  0.500000  0.712893
# 4  0.524288  0.363506  0.620252
# 5 -0.613728 -0.993737 -0.046311
# 6 -1.627440 -0.363428 -0.844697

# %%
_ = df.fillna(0,inplace=True)

# %%
df
# Out:
#           0         1         2
# 0  0.000000  0.000000  0.000000
# 1  0.610922  0.000000  0.000000
# 2 -0.170320  0.000000  0.473399
# 3 -0.487708  0.000000  0.712893
# 4  0.524288  0.363506  0.620252
# 5 -0.613728 -0.993737 -0.046311
# 6 -1.627440 -0.363428 -0.844697

# %%
df =pd.DataFrame(np.random.randn(6,3))

# %%
df
# Out:
#           0         1         2
# 0 -0.817604 -0.202398 -1.160839
# 1  0.656780 -0.431777 -0.041369
# 2 -0.655639  0.579041 -3.009001
# 3  0.713383 -1.591512  2.992954
# 4  1.438991 -0.497752  1.622303
# 5  1.172774 -0.661050  0.933554

# %%
df.iloc[2:,1]=NA

# %%
df.iloc[4:,2] = NA

# %%
df
# Out:
#           0         1         2
# 0 -0.817604 -0.202398 -1.160839
# 1  0.656780 -0.431777 -0.041369
# 2 -0.655639       NaN -3.009001
# 3  0.713383       NaN  2.992954
# 4  1.438991       NaN       NaN
# 5  1.172774       NaN       NaN

# %%
df.fillna(method='ffill')
# Out:
#           0         1         2
# 0 -0.817604 -0.202398 -1.160839
# 1  0.656780 -0.431777 -0.041369
# 2 -0.655639 -0.431777 -3.009001
# 3  0.713383 -0.431777  2.992954
# 4  1.438991 -0.431777  2.992954
# 5  1.172774 -0.431777  2.992954

# %%
df.fillna(method='ffill',limit=2)
# Out:
#           0         1         2
# 0 -0.817604 -0.202398 -1.160839
# 1  0.656780 -0.431777 -0.041369
# 2 -0.655639 -0.431777 -3.009001
# 3  0.713383 -0.431777  2.992954
# 4  1.438991       NaN  2.992954
# 5  1.172774       NaN  2.992954

# %%
data = pd.Series([1., NA, 3.5, NA, 7])

# %%
data.fillna(data.mean())
# Out:
# 0    1.000000
# 1    3.833333
# 2    3.500000
# 3    3.833333
# 4    7.000000
# dtype: float64

# %%
data = pd.DataFrame({'k1':['one','two']*3 + ['two'], 'k2':[1,1,2,3,3,4,4]})

# %%
data
# Out:
#     k1  k2
# 0  one   1
# 1  two   1
# 2  one   2
# 3  two   3
# 4  one   3
# 5  two   4
# 6  two   4

# %%
data.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6     True
# dtype: bool

# %%
data.describe()
# Out:
#              k2
# count  7.000000
# mean   2.571429
# std    1.272418
# min    1.000000
# 25%    1.500000
# 50%    3.000000
# 75%    3.500000
# max    4.000000

# %%
data.drop_duplicates()
# Out:
#     k1  k2
# 0  one   1
# 1  two   1
# 2  one   2
# 3  two   3
# 4  one   3
# 5  two   4

# %%
data['v1'] = range(7)

# %%
data
# Out:
#     k1  k2  v1
# 0  one   1   0
# 1  two   1   1
# 2  one   2   2
# 3  two   3   3
# 4  one   3   4
# 5  two   4   5
# 6  two   4   6

# %%
data.drop_duplicates(['k1','k2'],keep='last')
# Out:
#     k1  k2  v1
# 0  one   1   0
# 1  two   1   1
# 2  one   2   2
# 3  two   3   3
# 4  one   3   4
# 6  two   4   6

# %%
data = pd.DataFrame({'food': ['bacon', 'pulled pork', 'bacon','Pastrami', 'corned beef', 'Bacon','pastrami', 'honey ham', 'nova lox'], 'ounces': [4, 3, 12, 6, 7.5, 8, 3, 5, 6]})

# %%
data
# Out:
#           food  ounces
# 0        bacon     4.0
# 1  pulled pork     3.0
# 2        bacon    12.0
# 3     Pastrami     6.0
# 4  corned beef     7.5
# 5        Bacon     8.0
# 6     pastrami     3.0
# 7    honey ham     5.0
# 8     nova lox     6.0

# %%
meat_to_animal ={'bacon':'pig', 'pulled pork':'pig','pastrami': 'cow','corned beef': 'cow','honey ham': 'pig','nova lox': 'salmon'}

# %%
lowercased = data['food'].str.lower()

# %%
lowercased
# Out:
# 0          bacon
# 1    pulled pork
# 2          bacon
# 3       pastrami
# 4    corned beef
# 5          bacon
# 6       pastrami
# 7      honey ham
# 8       nova lox
# Name: food, dtype: object

# %%
data['animal'] = lowercased.map(meat_to_animal
                               )

# %%
data
# Out:
#           food  ounces  animal
# 0        bacon     4.0     pig
# 1  pulled pork     3.0     pig
# 2        bacon    12.0     pig
# 3     Pastrami     6.0     cow
# 4  corned beef     7.5     cow
# 5        Bacon     8.0     pig
# 6     pastrami     3.0     cow
# 7    honey ham     5.0     pig
# 8     nova lox     6.0  salmon

# %%
data['food'].map(lambda x : meat_to_animal[x.lower()])
# Out:
# 0       pig
# 1       pig
# 2       pig
# 3       cow
# 4       cow
# 5       pig
# 6       cow
# 7       pig
# 8    salmon
# Name: food, dtype: object

# %%
data = pd.Series([1., -999., 2., -999., -1000., 3.])

# %%
data
# Out:
# 0       1.0
# 1    -999.0
# 2       2.0
# 3    -999.0
# 4   -1000.0
# 5       3.0
# dtype: float64

# %%
data.replace(-999, np.nan)
# Out:
# 0       1.0
# 1       NaN
# 2       2.0
# 3       NaN
# 4   -1000.0
# 5       3.0
# dtype: float64

# %%
data.replace([-999,-1000], np.nan)
# Out:
# 0    1.0
# 1    NaN
# 2    2.0
# 3    NaN
# 4    NaN
# 5    3.0
# dtype: float64

# %%
data.replace([-999,-1000],[np.nan,0])
# Out:
# 0    1.0
# 1    NaN
# 2    2.0
# 3    NaN
# 4    0.0
# 5    3.0
# dtype: float64

# %%
data.replace({-999:np.nan, -1000:0})
# Out:
# 0    1.0
# 1    NaN
# 2    2.0
# 3    NaN
# 4    0.0
# 5    3.0
# dtype: float64

# %%
data = pd.DataFrame(np.arange(12).reshape((3, 4)), index=['Ohio', 'Colorado', 'New York'],columns=['one', 'two', 'three', 'four'])

# %%
transform = lambda x: x[:4].upper()

# %%
data.index.map(transform)
# Out:
# Index(['OHIO', 'COLO', 'NEW '], dtype='object')

# %%
data
# Out:
#           one  two  three  four
# Ohio        0    1      2     3
# Colorado    4    5      6     7
# New York    8    9     10    11

# %%
data.index =data.index.map(transform)

# %%
data
# Out:
#       one  two  three  four
# OHIO    0    1      2     3
# COLO    4    5      6     7
# NEW     8    9     10    11

# %%
data.rename(index=str.title,columns=str.upper)
# Out:
#       ONE  TWO  THREE  FOUR
# Ohio    0    1      2     3
# Colo    4    5      6     7
# New     8    9     10    11

# %%
data.rename(index={'OHIO':'INDIANA'}, columns={'three':'peekaboo'})
# Out:
#          one  two  peekaboo  four
# INDIANA    0    1         2     3
# COLO       4    5         6     7
# NEW        8    9        10    11

# %%
names.head(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-75-38d8bb2fb987> in <module>()
# ----> 1 names.head(10)
#
# NameError: name 'names' is not defined

# %%
ls
# Out:
#  驱动器 C 中的卷没有标签。
#  卷的序列号是 F432-453A
#
#  C:\Users\maozhang\pydata 的目录
#
# 2018/10/26  21:36    <DIR>          .
# 2018/10/26  21:36    <DIR>          ..
# 2018/10/26  16:20    <DIR>          .ipynb_checkpoints
# 2018/10/26  21:36            72,109 Dat Cleaning.ipynb
# 2018/10/26  11:51            58,319 Data Loading.ipynb
# 2018/10/23  14:21                80 ipython_script_test.py
# 2018/10/26  16:11           499,718 pandas_test.ipynb
# 2018/10/25  09:44    <DIR>          pydata-book-2nd-edition
# 2018/10/23  18:03            85,866 test01.ipynb
# 2018/10/25  10:25           847,716 test02.ipynb
# 2018/10/26  21:29           600,908 Untitled.ipynb
#                7 个文件      2,164,716 字节
#                4 个目录 364,579,045,376 可用字节

# %%
ls
# Out:
#  驱动器 C 中的卷没有标签。
#  卷的序列号是 F432-453A
#
#  C:\Users\maozhang\pydata 的目录
#
# 2018/10/26  21:38    <DIR>          .
# 2018/10/26  21:38    <DIR>          ..
# 2018/10/26  16:20    <DIR>          .ipynb_checkpoints
# 2018/10/26  21:38            73,186 Dat Cleaning.ipynb
# 2018/10/26  11:51            58,319 Data Loading.ipynb
# 2018/10/23  14:21                80 ipython_script_test.py
# 2018/10/26  21:38    <DIR>          names
# 2018/10/26  16:11           499,718 pandas_test.ipynb
# 2018/10/25  09:44    <DIR>          pydata-book-2nd-edition
# 2018/10/23  18:03            85,866 test01.ipynb
# 2018/10/25  10:25           847,716 test02.ipynb
# 2018/10/26  21:29           600,908 Untitled.ipynb
#                7 个文件      2,165,793 字节
#                5 个目录 364,546,973,696 可用字节

# %%
import pandas as pd

# %%
names1880 = pd.read_csv('names/yob1880.txt', names=['name','sex','births'])

# %%
names1880
# Out:
#            name sex  births
# 0          Mary   F    7065
# 1          Anna   F    2604
# 2          Emma   F    2003
# 3     Elizabeth   F    1939
# 4        Minnie   F    1746
# 5      Margaret   F    1578
# 6           Ida   F    1472
# 7         Alice   F    1414
# 8        Bertha   F    1320
# 9         Sarah   F    1288
# 10        Annie   F    1258
# 11        Clara   F    1226
# 12         Ella   F    1156
# 13     Florence   F    1063
# 14         Cora   F    1045
# 15       Martha   F    1040
# 16        Laura   F    1012
# 17       Nellie   F     995
# 18        Grace   F     982
# 19       Carrie   F     949
# 20        Maude   F     858
# 21        Mabel   F     808
# 22       Bessie   F     796
# 23       Jennie   F     793
# 24     Gertrude   F     787
# 25        Julia   F     783
# 26       Hattie   F     769
# 27        Edith   F     768
# 28       Mattie   F     704
# 29         Rose   F     700
# ...         ...  ..     ...
# 1970      Philo   M       5
# ...

# %%
names1880.groupby('sex').births.sum()
# Out:
# sex
# F     90993
# M    110491
# Name: births, dtype: int64

# %%
years = range(1880,2018)

# %%
pieces = []

# %%
columns = ['name','sex','births']

# %%
for year in years:
    path = 'names/yob%d.txt'%year
    frame = pd.read_csv(path,names=columns)
    
    frame['year'] = year
    pieces.append(frame)

# %%
pieces
# Out:
# [           name sex  births  year
#  0          Mary   F    7065  1880
#  1          Anna   F    2604  1880
#  2          Emma   F    2003  1880
#  3     Elizabeth   F    1939  1880
#  4        Minnie   F    1746  1880
#  5      Margaret   F    1578  1880
#  6           Ida   F    1472  1880
#  7         Alice   F    1414  1880
#  8        Bertha   F    1320  1880
#  9         Sarah   F    1288  1880
#  10        Annie   F    1258  1880
#  11        Clara   F    1226  1880
#  12         Ella   F    1156  1880
#  13     Florence   F    1063  1880
#  14         Cora   F    1045  1880
#  15       Martha   F    1040  1880
#  16        Laura   F    1012  1880
#  17       Nellie   F     995  1880
#  18        Grace   F     982  1880
#  19       Carrie   F     949  1880
#  20        Maude   F     858  1880
#  21        Mabel   F     808  1880
#  22       Bessie   F     796  1880
#  23       Jennie   F     793  1880
#  24     Gertrude   F     787  1880
#  25        Julia   F     783  1880
# ...

# %%
names = pd.concat(pieces,ignore_index=True)

# %%
names
# Out:
#               name sex  births  year
# 0             Mary   F    7065  1880
# 1             Anna   F    2604  1880
# 2             Emma   F    2003  1880
# 3        Elizabeth   F    1939  1880
# 4           Minnie   F    1746  1880
# 5         Margaret   F    1578  1880
# 6              Ida   F    1472  1880
# 7            Alice   F    1414  1880
# 8           Bertha   F    1320  1880
# 9            Sarah   F    1288  1880
# 10           Annie   F    1258  1880
# 11           Clara   F    1226  1880
# 12            Ella   F    1156  1880
# 13        Florence   F    1063  1880
# 14            Cora   F    1045  1880
# 15          Martha   F    1040  1880
# 16           Laura   F    1012  1880
# 17          Nellie   F     995  1880
# 18           Grace   F     982  1880
# 19          Carrie   F     949  1880
# 20           Maude   F     858  1880
# 21           Mabel   F     808  1880
# 22          Bessie   F     796  1880
# 23          Jennie   F     793  1880
# ...

# %%
total_births = names.pivot_table('births',index='year',columns='sex',aggfunc=sum)

# %%
total_births.tail()
# Out:
# sex         F        M
# year
# 2013  3500642  3773978
# 2014  3562144  3830478
# 2015  3557766  3819608
# 2016  3527832  3778104
# 2017  1711811  1834490

# %%
import matplotlib.pyplot as plt
total_births.plot(title='Total births by sex and year')

# %%
def add_prop(group):
    group['prop'] = group.births/group.births.sum()
    return group
names = names.groupby(['year','sex']).apply(add_prop)

# %%
names
# Out:
#               name sex  births  year      prop
# 0             Mary   F    7065  1880  0.038822
# 1             Anna   F    2604  1880  0.014309
# 2             Emma   F    2003  1880  0.011006
# 3        Elizabeth   F    1939  1880  0.010655
# 4           Minnie   F    1746  1880  0.009594
# 5         Margaret   F    1578  1880  0.008671
# 6              Ida   F    1472  1880  0.008089
# 7            Alice   F    1414  1880  0.007770
# 8           Bertha   F    1320  1880  0.007253
# 9            Sarah   F    1288  1880  0.007077
# 10           Annie   F    1258  1880  0.006913
# 11           Clara   F    1226  1880  0.006737
# 12            Ella   F    1156  1880  0.006352
# 13        Florence   F    1063  1880  0.005841
# 14            Cora   F    1045  1880  0.005742
# 15          Martha   F    1040  1880  0.005715
# 16           Laura   F    1012  1880  0.005561
# 17          Nellie   F     995  1880  0.005467
# 18           Grace   F     982  1880  0.005396
# ...

# %%
names.groupby(['year','sex']).prop.sum()
# Out:
# year  sex
# 1880  F      1.0
#       M      1.0
# 1881  F      1.0
#       M      1.0
# 1882  F      1.0
#       M      1.0
# 1883  F      1.0
#       M      1.0
# 1884  F      1.0
#       M      1.0
# 1885  F      1.0
#       M      1.0
# 1886  F      1.0
#       M      1.0
# 1887  F      1.0
#       M      1.0
# 1888  F      1.0
#       M      1.0
# 1889  F      1.0
#       M      1.0
# 1890  F      1.0
#       M      1.0
# 1891  F      1.0
#       M      1.0
# 1892  F      1.0
#       M      1.0
# 1893  F      1.0
#       M      1.0
# 1894  F      1.0
#       M      1.0
#             ...
# 2003  F      1.0
#       M      1.0
# 2004  F      1.0
#       M      1.0
# 2005  F      1.0
#       M      1.0
# 2006  F      1.0
#       M      1.0
# 2007  F      1.0
#       M      1.0
# 2008  F      1.0
#       M      1.0
# 2009  F      1.0
#       M      1.0
# 2010  F      1.0
#       M      1.0
# 2011  F      1.0
#       M      1.0
# 2012  F      1.0
#       M      1.0
# 2013  F      1.0
# ...

# %%
def get_top1000(group):
    return group.sort_values(by='births',ascending=False)[:1000]
grouped = names.groupby(['year','sex'])
top1000 = grouped.apply(get_top1000)

# %%
top1000
# Out:
#                        name sex  births  year      prop
# year sex
# 1880 F   0             Mary   F    7065  1880  0.038822
#          1892196       Mary   F    7065  1880  0.038822
#          1892197       Anna   F    2604  1880  0.014309
#          1             Anna   F    2604  1880  0.014309
#          1892198       Emma   F    2003  1880  0.011006
#          2             Emma   F    2003  1880  0.011006
#          1892199  Elizabeth   F    1939  1880  0.010655
#          3        Elizabeth   F    1939  1880  0.010655
#          1892200     Minnie   F    1746  1880  0.009594
#          4           Minnie   F    1746  1880  0.009594
#          5         Margaret   F    1578  1880  0.008671
#          1892201   Margaret   F    1578  1880  0.008671
#          1892202        Ida   F    1472  1880  0.008089
#          6              Ida   F    1472  1880  0.008089
#          1892203      Alice   F    1414  1880  0.007770
#          7            Alice   F    1414  1880  0.007770
# ...

# %%
top1000.reset_index(inplace=True,drop=True)

# %%
top1000
# Out:
#              name sex  births  year      prop
# 0            Mary   F    7065  1880  0.038822
# 1            Mary   F    7065  1880  0.038822
# 2            Anna   F    2604  1880  0.014309
# 3            Anna   F    2604  1880  0.014309
# 4            Emma   F    2003  1880  0.011006
# 5            Emma   F    2003  1880  0.011006
# 6       Elizabeth   F    1939  1880  0.010655
# 7       Elizabeth   F    1939  1880  0.010655
# 8          Minnie   F    1746  1880  0.009594
# 9          Minnie   F    1746  1880  0.009594
# 10       Margaret   F    1578  1880  0.008671
# 11       Margaret   F    1578  1880  0.008671
# 12            Ida   F    1472  1880  0.008089
# 13            Ida   F    1472  1880  0.008089
# 14          Alice   F    1414  1880  0.007770
# 15          Alice   F    1414  1880  0.007770
# 16         Bertha   F    1320  1880  0.007253
# 17         Bertha   F    1320  1880  0.007253
# 18          Sarah   F    1288  1880  0.007077
# ...

# %%
boys = top1000[top1000.sex == 'M']

# %%
girls = top1000[top1000.sex == 'F']

# %%
total_births = top1000.pivot_table('births', index='year',columns='name',aggfunc=sum)

# %%
total_births
# Out:
# name   Aaden  Aadhya  Aaliyah  Aarav    Aaron   Abbey  Abbie  Abbigail  \
# year
# 1880     NaN     NaN      NaN    NaN    204.0     NaN  142.0       NaN
# 1881     NaN     NaN      NaN    NaN    188.0     NaN  162.0       NaN
# 1882     NaN     NaN      NaN    NaN    170.0     NaN  160.0       NaN
# 1883     NaN     NaN      NaN    NaN    210.0     NaN  158.0       NaN
# 1884     NaN     NaN      NaN    NaN    194.0     NaN  196.0       NaN
# 1885     NaN     NaN      NaN    NaN    176.0     NaN  176.0       NaN
# 1886     NaN     NaN      NaN    NaN    172.0     NaN  168.0       NaN
# 1887     NaN     NaN      NaN    NaN    156.0     NaN  208.0       NaN
# 1888     NaN     NaN      NaN    NaN    180.0     NaN  274.0       NaN
# 1889     NaN     NaN      NaN    NaN    170.0     NaN  214.0       NaN
# 1890     NaN     NaN      NaN    NaN    192.0     NaN  280.0       NaN
# 1891     NaN     NaN      NaN    NaN    138.0     NaN  248.0       NaN
# ...

# %%
total_births.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 138 entries, 1880 to 2017
# Columns: 3718 entries, Aaden to Zyaire
# dtypes: float64(3718)
# memory usage: 3.9 MB

# %%
subset = total_births[['John','Harry','Mary','Marilyn']]

# %%
subset.plot(subplots=True, figsize=(12,10),grid=False,title='Number of births per year')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000021101487390>,
# ...
#       dtype=object)

# %%
table = top1000.pivot_table('prop',index='year',columns='sex',aggfunc=sum)

# %%
table.plot(title='Sum of top1000.prop by year and sex', yticks=np.linspace(0,1.2,5),xticks=range(1880,2020,20), grid=True)

# %%
df = boys[boys.year == 2010]

# %%
df
# Out:
#                name sex  births  year      prop
# 261000        Jacob   M   22117  2010  0.005772
# 261001        Jacob   M   22117  2010  0.005772
# 261002        Ethan   M   18000  2010  0.004697
# 261003        Ethan   M   18000  2010  0.004697
# 261004      Michael   M   17342  2010  0.004526
# 261005      Michael   M   17342  2010  0.004526
# 261006       Jayden   M   17171  2010  0.004481
# 261007       Jayden   M   17171  2010  0.004481
# 261008      William   M   17048  2010  0.004449
# 261009      William   M   17048  2010  0.004449
# 261010    Alexander   M   16752  2010  0.004372
# 261011    Alexander   M   16752  2010  0.004372
# 261012         Noah   M   16447  2010  0.004292
# 261013         Noah   M   16447  2010  0.004292
# 261014       Daniel   M   15836  2010  0.004133
# 261015       Daniel   M   15836  2010  0.004133
# 261016        Aiden   M   15535  2010  0.004054
# 261017        Aiden   M   15535  2010  0.004054
# 261018      Anthony   M   15487  2010  0.004042
# ...

# %%
prop_cusum = df.sort_values(by='prop',ascending=False).prop.cumsum()

# %%
prop_cusum[:10]
# Out:
# 261000    0.005772
# 261001    0.011544
# 261002    0.016241
# 261003    0.020939
# 261004    0.025464
# 261005    0.029990
# 261006    0.034471
# 261007    0.038952
# 261008    0.043401
# 261009    0.047850
# Name: prop, dtype: float64

# %%
prop_cusum.values.searchsorted(0.5)
# Out:
# 233

# %%
df = boys[boys.year == 1900]

# %%
in1900 = df.sort_values(by='prop',ascending=False).prop.cumsum()

# %%
in1900.values.searchsorted(0.5)+1
# Out:
# 50

# %%
def get_quantile_count(group, q=0.5):
    group = group.sort_values(by='prop',ascending=False)
    return group.prop.cumsum().values.searchsorted(q)+1

# %%
divesity = top1000.groupby(['year','sex']).apply(get_quantile_count)

# %%
divesity
# Out:
# year  sex
# 1880  F       75
#       M       27
# 1881  F       75
#       M       27
# 1882  F       76
#       M       29
# 1883  F       77
#       M       29
# 1884  F       78
#       M       31
# 1885  F       79
#       M       32
# 1886  F       81
#       M       32
# 1887  F       82
#       M       33
# 1888  F       84
#       M       34
# 1889  F       85
#       M       35
# 1890  F       87
#       M       37
# 1891  F       87
#       M       39
# 1892  F       87
#       M       40
# 1893  F       88
#       M       41
# 1894  F       90
#       M       43
#             ...
# 2003  F      357
#       M      174
# 2004  F      382
#       M      183
# 2005  F      398
#       M      191
# 2006  F      418
#       M      198
# 2007  F      446
#       M      206
# 2008  F      468
#       M      217
# 2009  F      482
#       M      227
# 2010  F      492
#       M      234
# 2011  F      488
#       M      239
# 2012  F      495
#       M      247
# 2013  F      481
# ...

# %%
divesity = divesity.unstack('sex')

# %%
divesity
# Out:
# sex     F    M
# year
# 1880   75   27
# 1881   75   27
# 1882   76   29
# 1883   77   29
# 1884   78   31
# 1885   79   32
# 1886   81   32
# 1887   82   33
# 1888   84   34
# 1889   85   35
# 1890   87   37
# 1891   87   39
# 1892   87   40
# 1893   88   41
# 1894   90   43
# 1895   91   44
# 1896   91   46
# 1897   92   46
# 1898   94   47
# 1899   93   49
# 1900   97   50
# 1901   97   50
# 1902   97   51
# 1903   97   53
# 1904   99   55
# 1905   99   56
# 1906   97   56
# 1907   99   59
# 1908   97   59
# 1909   98   60
# ...   ...  ...
# 1988  156   80
# 1989  166   86
# 1990  180   90
# 1991  190   95
# 1992  204  101
# 1993  213  107
# 1994  223  113
# 1995  230  120
# 1996  243  128
# 1997  258  134
# 1998  275  139
# 1999  292  145
# 2000  309  154
# 2001  329  161
# 2002  339  165
# 2003  357  174
# 2004  382  183
# 2005  398  191
# 2006  418  198
# 2007  446  206
# 2008  468  217
# 2009  482  227
# 2010  492  234
# 2011  488  239
# 2012  495  247
# 2013  481  252
# ...

# %%
divesity.head()
# Out:
# sex    F   M
# year
# 1880  75  27
# 1881  75  27
# 1882  76  29
# 1883  77  29
# 1884  78  31

# %%
divesity.plot(title='Number of pouplar names in top 50%')

# %%
get_last_letter = lambda x : x[-1]

last_letters = names.name.map(get_last_letter)

last_letters.name = 'last_letter'

# %%
last_letters
# Out:
# 0          y
# 1          a
# 2          a
# 3          h
# 4          e
# 5          t
# 6          a
# 7          e
# 8          a
# 9          h
# 10         e
# 11         a
# 12         a
# 13         e
# 14         a
# 15         a
# 16         a
# 17         e
# 18         e
# 19         e
# 20         e
# 21         l
# 22         e
# 23         e
# 24         e
# 25         a
# 26         e
# 27         h
# 28         e
# 29         e
#           ..
# 3816831    r
# 3816832    r
# 3816833    i
# 3816834    a
# 3816835    e
# 3816836    d
# 3816837    h
# 3816838    o
# 3816839    k
# 3816840    n
# 3816841    n
# 3816842    n
# 3816843    r
# 3816844    a
# 3816845    n
# 3816846    g
# 3816847    i
# 3816848    n
# 3816849    n
# 3816850    n
# 3816851    r
# 3816852    y
# 3816853    l
# 3816854    m
# 3816855    r
# 3816856    i
# 3816857    m
# 3816858    n
# 3816859    s
# 3816860    e
# Name: last_letter, Length: 3816861, dtype: object

# %%
table = names.pivot_table('births', index = last_letters, columns=['sex','year'],aggfunc=sum)

# %%
table
# Out:
# sex                F                                                         \
# year            1880     1881     1882     1883     1884     1885      1886
# last_letter
# a            62892.0  63162.0  73072.0  76658.0  87360.0  90816.0   98200.0
# b                NaN      NaN      NaN      NaN      NaN      NaN       NaN
# c                NaN      NaN     10.0     10.0      NaN      NaN       NaN
# d             1218.0   1214.0   1468.0   1620.0   1832.0   1724.0    2014.0
# e            66760.0  68160.0  80798.0  83826.0  96178.0  99232.0  107766.0
# f                NaN      NaN      NaN      NaN      NaN      NaN       NaN
# g               14.0     10.0     24.0     16.0     48.0     22.0      36.0
# h             9726.0   9566.0  11132.0  11402.0  13204.0  13246.0   14292.0
# i              122.0    156.0    162.0    152.0    168.0    184.0     170.0
# j                NaN      NaN      NaN      NaN      NaN      NaN       NaN
# ...

# %%
subtable = table.reindex(columns=[1910,1960,2010], level='year')

# %%
subtable
# Out:
# sex                 F                              M
# year             1910       1960       2010     1910      1960       2010
# last_letter
# a            216794.0  1382500.0  1353292.0   1954.0   10424.0    57718.0
# b                 NaN     1388.0      910.0    822.0    7828.0    78528.0
# c                10.0       98.0     1910.0    964.0   30920.0    46682.0
# d             13502.0     7460.0     5280.0  44226.0  524272.0    89634.0
# e            267200.0   870086.0   633330.0  57330.0  357570.0   260456.0
# f                 NaN       40.0      194.0    304.0   18460.0     4620.0
# g               114.0      636.0     1338.0    878.0   40456.0     5390.0
# h             40864.0   146476.0   269644.0  17700.0  161674.0   198544.0
# i              1210.0   161630.0   112518.0    328.0    2590.0    86860.0
# j                 NaN        NaN      328.0      NaN       NaN     2956.0
# k                96.0      628.0     1262.0  14208.0  210592.0    71020.0
# ...

# %%
subtable.replace(np.nan,0.)
# Out:
# sex                 F                              M
# year             1910       1960       2010     1910      1960       2010
# last_letter
# a            216794.0  1382500.0  1353292.0   1954.0   10424.0    57718.0
# b                 0.0     1388.0      910.0    822.0    7828.0    78528.0
# c                10.0       98.0     1910.0    964.0   30920.0    46682.0
# d             13502.0     7460.0     5280.0  44226.0  524272.0    89634.0
# e            267200.0   870086.0   633330.0  57330.0  357570.0   260456.0
# f                 0.0       40.0      194.0    304.0   18460.0     4620.0
# g               114.0      636.0     1338.0    878.0   40456.0     5390.0
# h             40864.0   146476.0   269644.0  17700.0  161674.0   198544.0
# i              1210.0   161630.0   112518.0    328.0    2590.0    86860.0
# j                 0.0        0.0      328.0      0.0       0.0     2956.0
# k                96.0      628.0     1262.0  14208.0  210592.0    71020.0
# ...

# %%
subtable.sum()
# Out:
# sex  year
# F    1910     793004.0
#      1960    4044036.0
#      2010    3549516.0
# M    1910     388426.0
#      1960    4264718.0
#      2010    3831884.0
# dtype: float64

# %%
letter_prop = subtable / subtable.sum()

# %%
letter_prop
# Out:
# sex                 F                             M
# year             1910      1960      2010      1910      1960      2010
# last_letter
# a            0.273383  0.341861  0.381261  0.005031  0.002444  0.015063
# b                 NaN  0.000343  0.000256  0.002116  0.001836  0.020493
# c            0.000013  0.000024  0.000538  0.002482  0.007250  0.012183
# d            0.017026  0.001845  0.001488  0.113860  0.122932  0.023392
# e            0.336947  0.215153  0.178427  0.147596  0.083844  0.067971
# f                 NaN  0.000010  0.000055  0.000783  0.004329  0.001206
# g            0.000144  0.000157  0.000377  0.002260  0.009486  0.001407
# h            0.051531  0.036220  0.075966  0.045569  0.037910  0.051814
# i            0.001526  0.039967  0.031700  0.000844  0.000607  0.022668
# j                 NaN       NaN  0.000092       NaN       NaN  0.000771
# k            0.000121  0.000155  0.000356  0.036578  0.049380  0.018534
# ...

# %%
letter_prop.replace(np.nan,0.,inplace=True)

# %%
letter_prop
# Out:
# sex                 F                             M
# year             1910      1960      2010      1910      1960      2010
# last_letter
# a            0.273383  0.341861  0.381261  0.005031  0.002444  0.015063
# b            0.000000  0.000343  0.000256  0.002116  0.001836  0.020493
# c            0.000013  0.000024  0.000538  0.002482  0.007250  0.012183
# d            0.017026  0.001845  0.001488  0.113860  0.122932  0.023392
# e            0.336947  0.215153  0.178427  0.147596  0.083844  0.067971
# f            0.000000  0.000010  0.000055  0.000783  0.004329  0.001206
# g            0.000144  0.000157  0.000377  0.002260  0.009486  0.001407
# h            0.051531  0.036220  0.075966  0.045569  0.037910  0.051814
# i            0.001526  0.039967  0.031700  0.000844  0.000607  0.022668
# j            0.000000  0.000000  0.000092  0.000000  0.000000  0.000771
# k            0.000121  0.000155  0.000356  0.036578  0.049380  0.018534
# ...

# %%
import matplotlib.pyplot as plt

# %%
fig, axes = plt.subplots(2,1, figsize=(20,5))
letter_prop['M'].plot(kind='bar',rot=0,ax=axes[0],title='Male')
letter_prop['F'].plot(kind='bar',rot=0,ax=axes[1],title='Female',legend=False)

# %%
axes
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000002110222CCC0>,
# ...
#       dtype=object)

# %%
letter_prop =table /table.sum()

# %%
letter_prop
# Out:
# sex                 F                                                    \
# year             1880      1881      1882      1883      1884      1885
# last_letter
# a            0.345587  0.343447  0.338776  0.341251  0.338552  0.341272
# b                 NaN       NaN       NaN       NaN       NaN       NaN
# c                 NaN       NaN  0.000046  0.000045       NaN       NaN
# d            0.006693  0.006601  0.006806  0.007212  0.007100  0.006479
# e            0.366841  0.370624  0.374595  0.373160  0.372725  0.372898
# f                 NaN       NaN       NaN       NaN       NaN       NaN
# g            0.000077  0.000054  0.000111  0.000071  0.000186  0.000083
# h            0.053444  0.052016  0.051610  0.050757  0.051170  0.049776
# i            0.000670  0.000848  0.000751  0.000677  0.000651  0.000691
# j                 NaN       NaN       NaN       NaN       NaN       NaN
# k            0.000143  0.000163  0.000102  0.000151  0.000163  0.000135
# ...

# %%
dny_ts = letter_prop.loc[['d','n','y'],'M'].T

# %%
dny_ts
# Out:
# last_letter         d         n         y
# year
# 1880         0.083057  0.153216  0.075762
# 1881         0.083242  0.153212  0.077455
# 1882         0.085332  0.149561  0.077538
# 1883         0.084051  0.151653  0.079148
# 1884         0.086122  0.149927  0.080408
# 1885         0.085474  0.146346  0.081884
# 1886         0.087648  0.149661  0.081681
# 1887         0.089071  0.148837  0.082869
# 1888         0.087711  0.151285  0.084923
# 1889         0.091915  0.151990  0.086336
# 1890         0.093826  0.146472  0.086278
# 1891         0.094485  0.148353  0.084929
# 1892         0.096390  0.144859  0.084885
# 1893         0.098319  0.142560  0.084635
# 1894         0.100459  0.142119  0.085558
# 1895         0.100030  0.143345  0.083334
# 1896         0.102871  0.140624  0.083928
# 1897         0.101980  0.140115  0.083276
# 1898         0.104882  0.139563  0.090635
# 1899         0.105009  0.140608  0.084804
# 1900         0.102902  0.137610  0.084674
# ...

# %%
dny_ts.plot()

# %%
all_names = pd.Series(top1000.name.unique())

# %%
all_names
# Out:
# 0            Mary
# 1            Anna
# 2            Emma
# 3       Elizabeth
# 4          Minnie
# 5        Margaret
# 6             Ida
# 7           Alice
# 8          Bertha
# 9           Sarah
# 10          Annie
# 11          Clara
# 12           Ella
# 13       Florence
# 14           Cora
# 15         Martha
# 16          Laura
# 17         Nellie
# 18          Grace
# 19         Carrie
# 20          Maude
# 21          Mabel
# 22         Bessie
# 23         Jennie
# 24       Gertrude
# 25          Julia
# 26         Hattie
# 27          Edith
# 28         Mattie
# 29           Rose
#           ...
# 3688     Tristian
# 3689       Vivaan
# 3690      Bridger
# 3691      Agustin
# 3692      Brayson
# 3693         Leif
# 3694        Bjorn
# 3695      Ignacio
# 3696      Greysen
# 3697         Kyng
# 3698       Gatlin
# 3699       Shmuel
# 3700        Zahir
# 3701        Khari
# 3702       Yadiel
# 3703       Ledger
# 3704          Avi
# 3705       Maddux
# 3706       Seamus
# ...

# %%
lesley_like = all_names[all_names.str.lower().str.contains('lesl')]

# %%
lesley_like
# Out:
# 658     Leslie
# 1945    Lesley
# 2815     Lesly
# dtype: object

# %%
filtered = top1000[top1000.name.isin(lesley_like)]

# %%
filtered
# Out:
#           name sex  births  year      prop
# 1328    Leslie   M      79  1880  0.000357
# 1331    Leslie   M      79  1880  0.000357
# 3265    Leslie   M      92  1881  0.000457
# 3269    Leslie   M      92  1881  0.000457
# 5234    Leslie   M     122  1882  0.000537
# 5236    Leslie   M     122  1882  0.000537
# 7214    Leslie   M     120  1883  0.000573
# 7217    Leslie   M     120  1883  0.000573
# 9228    Leslie   M     125  1884  0.000546
# 9229    Leslie   M     125  1884  0.000546
# 11222   Leslie   M     122  1885  0.000566
# 11223   Leslie   M     122  1885  0.000566
# 13227   Leslie   M     136  1886  0.000614
# 13228   Leslie   M     136  1886  0.000614
# 15178   Leslie   M     166  1887  0.000818
# 15179   Leslie   M     166  1887  0.000818
# 17197   Leslie   M     175  1888  0.000724
# 17198   Leslie   M     175  1888  0.000724
# 19209   Leslie   M     155  1889  0.000701
# 19211   Leslie   M     155  1889  0.000701
# 21190   Leslie   M     181  1890  0.000815
# ...

# %%
filtered.groupby('name').births.sum()
# Out:
# name
# Lesley     44590
# Leslie    742151
# Lesly      16086
# Name: births, dtype: int64

# %%
table = filtered.pivot_table('births',index='year',columns='sex',aggfunc='sum')

# %%
table.tail()
# Out:
# sex        F   M
# year
# 2013  2222.0 NaN
# 2014  2000.0 NaN
# 2015  1756.0 NaN
# 2016  1604.0 NaN
# 2017   701.0 NaN

# %%
table = table.div(table.sum(1), axis=0)

# %%
table.tail()
# Out:
# sex     F   M
# year
# 2013  1.0 NaN
# 2014  1.0 NaN
# 2015  1.0 NaN
# 2016  1.0 NaN
# 2017  1.0 NaN

# %%
table.replace(np.nan, 0, inplace=True)

# %%
table.plot(style={'M':'k-','F':'k--'})
